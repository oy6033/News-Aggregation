# %%
import pandas as pd
import numpy as np
import re
import string
import nltk
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
stemmer= PorterStemmer()
lemmatizer = WordNetLemmatizer()
from gensim.models import FastText
from gensim.models import doc2vec
from gensim.models import Doc2Vec

# %%
company ='APPLE'
time = 1440
file = 'Labeled_news/'+company+'_'+str(time)+'_labeled_news.csv'

# %%
df_news = pd.read_csv(file)

# %%
df_news['Text'] = df_news['Text'].str.lower()

# %%
def cleaning(text):
    text = re.sub(r'\d+','', text)
    text = text.translate(str.maketrans('','',string.punctuation))
    text = text.strip()
    tokens = word_tokenize(text)
    text_array = [i for i in tokens if not i in ENGLISH_STOP_WORDS]
    result =[]
    for text in text_array:
        result.append(lemmatizer.lemmatize(text))
    return result

# %%
df_news['Text'] = df_news['Text'].apply(cleaning)

# %%
# from gensim.models import KeyedVectors

# en_model = KeyedVectors.load_word2vec_format('data/wiki.vec')

# model_DBOW = Doc2Vec(dm=0,size=600,window=15,hs=0,negative=5,min_count=5,dbow_words=1,sample=1e-5)

# df_news['Text'].to_csv('news.txt')

# X, y = (df_news['Text'].values, df_news['Positive_Sentiment'].values)

# from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
# tk = Tokenizer(lower = True)
# tk.fit_on_texts(X)
# X_seq = tk.texts_to_sequences(X)
# X_pad = pad_sequences(X_seq, maxlen=100, padding='post')

# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X_pad, y, test_size = 0.25, random_state = 1)

# batch_size = 64
# X_train1 = X_train[batch_size:]
# y_train1 = y_train[batch_size:]
# X_valid = X_train[:batch_size]
# y_valid = y_train[:batch_size]

# from keras.models import Sequential
# from keras.layers import Embedding, LSTM, Dense, Dropout
# vocabulary_size = len(tk.word_counts.keys())+1
# max_words = 100
# embedding_size = 32
# model = Sequential()
# model.add(Embedding(vocabulary_size, embedding_size, input_length=max_words))
# model.add(LSTM(200))
# model.add(Dense(1, activation='sigmoid'))
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# model.fit(X_train1,y_train1,validation_data = (X_valid,y_valid),batch_size=batch_size,epochs=10)

# %%
df_news.to_csv(company+'_'+str(time)+'_cleaned_news.csv')

# %%
df_news
# Out:
#        Unnamed: 0       Published_date  \
# 0               0  2017-12-04 14:00:00
# 1               2  2017-12-20 08:37:00
# 2               7  2017-12-18 14:00:00
# 3              16  2017-12-14 04:22:00
# 4              21  2017-11-29 14:00:00
# 5              23  2017-11-30 10:13:00
# 6              24  2017-12-22 14:00:00
# 7              30  2017-12-28 12:47:00
# 8              48  2017-12-06 11:43:00
# 9              50  2017-12-21 14:00:00
# 10             70  2017-12-02 14:00:00
# 11             83  2017-11-30 14:00:00
# 12             87  2017-12-08 23:42:00
# 13             89  2017-12-11 12:23:00
# 14             93  2017-12-27 14:00:00
# 15             96  2017-12-06 12:16:00
# 16            100  2017-12-19 08:35:00
# 17            104  2017-12-28 14:00:00
# 18            106  2017-12-28 14:00:00
# 19            107  2017-12-11 14:00:00
# 20            119  2017-12-07 16:55:00
# 6      [investor, sitting, share, iphone, maker, far,...  2017-12-22
# 7      [年月日（金）, 「シカゴ日経平均先物（ｃｍｅ）」（日）marｏ, （ドル建て）ｈ, ｌ, ...  2017-12-28
# 8      [apple, aapl, wednesday, fixed, major, shortco...  2017-12-06
# 9      [amazoncom, amzn, related, video, charlie, mun...  2017-12-21
# 10     [bloomberg, tv, brings, latest, business, mark...  2017-12-02
# 11     [bloomberg, tv, brings, latest, business, mark...  2017-11-30
# 12     [今回は、前回の「転換線」＋「基準線」＋「雲」に「遅行スパン」（遅行線）を加えて株価チャート...  2017-12-09
# 13     [travel, documentary, day, cairo, egypt, far, ...  2017-12-11
# 14     [scale, faang, rally, —, apple, aapl, year, fa...  2017-12-27
# 15     [uhr, die, amazon, prime, video, app, ist, ab,...  2017-12-06
# 16     [consumer, using, disneyfox, netflix, youtube,...  2017-12-19
# 17     [boeing, share, enjoyed, gain, venerable, blue...  2017-12-28
# 18     [active, management, win, active, management, ...  2017-12-28
# 19     [▼, amazoncom, amzn, sector, grappling, challe...  2017-12-11
# 20     [amazon, google, duking, newsfeedbackfoolcom, ...  2017-12-07
# 21     [deal, cramer, said, defend, fang, name, faceb...  2017-11-30
# 22     [heavilyweighted, tech, stock, set, drive, act...  2017-11-30
# 23     [heavilyweighted, tech, stock, set, drive, act...  2017-11-30
# 24     [welcome, radio, station, ending, stream, favo...  2017-12-05
# 25     [apple, google, face, lot, challenger, fragmen...  2017-12-12
# 26     [jack, say, spirit, free, —, listen, song, itu...  2017-11-28
# 27     [asked, trio, motley, fool, contributor, look,...  2017-12-10
# 28     [investor, heavily, concentrated, faang, stock...  2017-12-26
# 29     [supporting, dow, ’, s, run, intraday, trade, ...  2017-11-30
# ...                                                  ...         ...
# 13094  [amazoncom, millionaire, maker, stock, publish...  2018-09-09
# 13095  [apple, iphone, bigger, online, store, amazon,...  2018-09-09
# 13096  [analyst, pricetarget, hike, lifted, googlepar...  2018-08-28
# 13097  [musk, doe, need, lot, check, balance, managem...  2018-09-18
# 13098  [cocacola, nyseko, amid, news, buying, coffee,...  2018-08-31
# 13099  [rumor, true, amazoncom, nasdaqamzn, myriad, p...  2018-09-19
# 13100  [reduce, weighting, tech, sector, retains, app...  2018-09-24
# 13101  [quarter, seen, major, gadget, release, consum...  2018-09-28
# 13102  [اسرار, الاسبوع, أنضمت, أمازون, amzno, يوم, ال...  2018-09-04
# 13103  [economist, targeting, nonfarm, payroll, rise,...  2018-09-02
# 13104  [yesterday, ’, s, market, equity, shook, bit, ...  2018-09-11
# 13105  [micron, technology, incmu, share, fell, day, ...  2018-09-20
# 13106  [亚马逊, 公司（amzno）周二（月日）加入, 苹果, 公司（aaplo），成为美国第二家...  2018-09-04
# 13107  [tuesday, ’, s, stock, market, trading, dow, j...  2018-09-11
# 13108  [סגירה, פתיחה, גבוה, נמוך, מחזור, לעמוד, ציטוט...  2018-08-31
# 13109  [spring, amazon, nasdaqamzn, share, topped, ti...  2018-09-13
# 13110  [rbc, capital, market, lifted, price, target, ...  2018-09-06
# 13111  [apple, amazon, went, lower, new, downtrend, j...  2018-09-26
# 13112  [home, », loudoun, county, va, news, », loudou...  2018-09-25
# 13113  [amazon, amzn, thursday, announced, bevy, new,...  2018-09-19
# 13114  [according, goldman, sachs, facebook, alphabet...  2018-09-24
# 13115  [documented, columbia, university, professor, ...  2018-09-13
# 13116  [amazon, prime, video, amzn, mobile, llc, comp...  2018-09-11
# 13117  [micron, technology, incmu, share, fell, day, ...  2018-09-20
# 13118  [uncertainty, increased, end, week, appeared, ...  2018-08-31
# 13119  [parallel, concentration, gain, faang, stocks—...  2018-09-13
# 13120  [amazoncom, amzn, split, avoid, antitrust, scr...  2018-09-16
# 13121  [apple, aapl, surpassing, trillion, hard, imag...  2018-09-17
# 13122  [thanks, upgrade, drilling, tech, stock, advan...  2018-09-04
# 13123  [chaikin同时指出，上周科技股的大幅下跌为投资者创造了买进的机会。他表示：, “, 尽...  2018-09-10
#
#            Time  Positive_Sentiment
# 0      16:00:00                True
# 1      10:37:00                True
# 2      16:00:00               False
# 3      06:22:00                True
# 4      16:00:00                True
# 5      12:13:00               False
# 6      16:00:00               False
# 7      14:47:00                True
# 8      13:43:00               False
# 9      16:00:00               False
# 10     16:00:00               False
# 11     16:00:00               False
# 12     01:42:00                True
# 13     14:23:00                True
# 14     16:00:00               False
# 15     14:16:00               False
# 16     10:35:00                True
# 17     16:00:00                True
# 18     16:00:00                True
# 19     16:00:00                True
# 20     18:55:00                True
# 21     11:38:00               False
# 22     16:00:00               False
# 23     16:00:00               False
# 24     16:00:00               False
# 25     16:00:00               False
# 26     16:00:00                True
# 27     16:00:00               False
# 28     16:00:00               False
# 29     16:00:00               False
# ...         ...                 ...
# 13094  11:48:00                True
# 13095  00:00:00               False
# 13096  16:00:00                True
# 13097  16:00:00                True
# 13098  13:38:00                True
# 13099  16:00:00               False
# 13100  13:35:00               False
# 13101  09:11:00               False
# 13102  09:28:00               False
# 13103  07:13:00                True
# 13104  16:00:00                True
# 13105  16:00:00                True
# 13106  23:51:00               False
# 13107  16:00:00                True
# 13108  15:02:00                True
# 13109  16:00:00               False
# 13110  08:48:00               False
# 13111  10:31:00                True
# 13112  10:57:00                True
# 13113  16:00:00               False
# 13114  18:44:00               False
# 13115  20:52:00               False
# 13116  12:22:00                True
# 13117  16:00:00                True
# 13118  21:17:00                True
# 13119  08:00:00               False
# 13120  16:00:00               False
# 13121  07:41:00                True
# 13122  16:00:00               False
# 13123  14:17:00               False
#
# [13124 rows x 7 columns]
